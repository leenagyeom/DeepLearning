# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python /content/drive/MyDrive/colab/data_call.py --data FaceMaskDetection

# %%
# !python /content/data_split.py

# %%
# !python /content/custom_data.py
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100% 97.8M/97.8M [00:00<00:00, 310MB/s]
# loss >> 1.8102145195007324 epoch >>  0 index >>  0 time : 1.9132275581359863
# loss >> 1.8187520503997803 epoch >>  0 index >>  10 time : 17.553032398223877
# loss >> 1.840592861175537 epoch >>  0 index >>  20 time : 32.73158597946167
# libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
# loss >> 1.727463960647583 epoch >>  0 index >>  30 time : 48.21083378791809
# loss >> 1.6873337030410767 epoch >>  0 index >>  40 time : 63.57549262046814
# loss >> 1.6646385192871094 epoch >>  0 index >>  50 time : 79.64207363128662
# loss >> 1.6609724760055542 epoch >>  0 index >>  60 time : 94.88731908798218
# loss >> 1.532201886177063 epoch >>  0 index >>  70 time : 109.93247509002686
# loss >> 1.2436509132385254 epoch >>  0 index >>  80 time : 125.37010216712952
# ...
